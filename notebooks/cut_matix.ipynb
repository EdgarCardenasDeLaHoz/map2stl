# %%
import numpy as np 
import glob
import matplotlib.pyplot as plt

# %%
root = "C:/Users/eac84/OneDrive/Documents/Projects/3D Maps/Map_files/Japans"

# %%
fns = glob.glob(root + "/*.np*")

# %%
fns[0]
# Out:
# 'C:/Users/eac84/OneDrive/Documents/Projects/3D Maps/Map_files/Japans\\Japans.npy'

# %%
im = np.load(fns[0])

# %%
nx = 2
ny = 2

# %%
bounds_min, bounds_max = [0,0],im.shape 


x_vals = np.linspace(bounds_min[0], bounds_max[0], nx + 1).astype(int)
y_vals = np.linspace(bounds_min[1], bounds_max[1], ny + 1).astype(int)

planes = []
for i in range(nx):
	for j in range(ny):
		xmin, xmax = x_vals[i].round(), x_vals[i + 1].round()
		ymin, ymax = y_vals[j].round(), y_vals[j + 1].round()
		print(xmin, xmax, ymin, ymax)
# Out:
# 0 315 0 245
# 0 315 245 490
# 315 631 0 245
# 315 631 245 490
